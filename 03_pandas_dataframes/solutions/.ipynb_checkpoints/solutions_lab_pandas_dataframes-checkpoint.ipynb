# %% [markdown]
# <p style="text-align: right; font-size: small;">
# Learning materials by Tamsin Huggins
# </p>

# %%
import pandas as pd
df = pd.read_csv("../data/kc_house_data.csv")

# %% [markdown]
# ### <span style="color:green"> Challenge 1: find the maximum number of bedrooms. </span>

# %%
df['bedrooms'].max()
# Out:
# 33

# %% [markdown]
# ### <span style="color:green"> Challenge 2: how old is the oldest house? </span>

# %%
2023 - df['yr_built'].min()
# Out:
# 123

# %% [markdown]
# ### <span style="color:green"> Challenge 3: create a new DataFrame holding only the properties that are by the waterfront. </span>
# <span style="color:green"> Assign your new DataFrame to a variable (call it waterfront_houses). </span>
#
#
# <span style="color:green"> Hint 1: houses by the waterfront have a value of 1 in the waterfront column, whereas houses not by the waterfront have a value of 0. </span>
#
# <span style="color:green"> Hint 2: Start by making your condition. Look a few cells up to see how this is done </span>

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df['waterfront'].unique() # unique values in waterfront column. It only has 1 meaning by waterfront, and 0 meaning not by waterfront
# Out:
# array([0, 1], dtype=int64)

# %%
condition = df['waterfront'] == 1 
waterfront_df = df[condition]
waterfront_df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 230    8096000060  20150413T000000   655000.0         2       1.75
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 264    2123039032  20141027T000000   369900.0         1       0.75
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# ...           ...              ...        ...       ...        ...
# 19984  2025069140  20150317T000000  1898000.0         3       2.50
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %% [markdown]
# ### <span style="color:green"> Challenge 4: find out how much being by the waterfront affects the price of properties. </span>
#
#
# <span style="color:green"> Hint: you can use the waterfront_houses dataframe you already made... </span>

# %%
waterfront_df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 230    8096000060  20150413T000000   655000.0         2       1.75
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# 264    2123039032  20141027T000000   369900.0         1       0.75
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# ...           ...              ...        ...       ...        ...
# 19984  2025069140  20150317T000000  1898000.0         3       2.50
# 20325   518500480  20140811T000000  3000000.0         3       3.50
# 20767  8043700105  20150417T000000  2300000.0         4       4.00
# 21201   518500460  20141008T000000  2230000.0         3       3.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 49            2753     65005     1.0           1     2  ...      9
# ...

# %% [markdown]
# create a non-waterfront dataframe

# %%
condition2 = df['waterfront'] == 0 
no_water_df = df[condition2] 
no_water_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %% [markdown]
# compare the average prices of waterfront vs non waterfront houses

# %%
waterfront_df['price'].mean()
# Out:
# 1661876.0245398772

# %%
no_water_df['price'].mean()
# Out:
# 531563.5998135199
