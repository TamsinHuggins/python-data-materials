# %% [markdown]
# <p style="text-align: right; font-size: small;">
# Learning materials by Tamsin Huggins
# </p>

# %% [markdown]
# # Challenge 1: Winter Olympics

# %% [markdown]
# 1) Import the Pandas package as pd

# %%
import pandas as pd

# %% [markdown]
# 2) Read in the data and save it to a variable called df. The data is held in a CSV file called winter in the Data folder.

# %%
df = pd.read_csv('../data/winter.csv')
df
# Out:
#       Year      City     Sport Discipline               Athlete Country  \
# 0     1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA
# 1     1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA
# 2     1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA
# 3     1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA
# 4     1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI
# ...    ...       ...       ...        ...                   ...     ...
# 5765  2014     Sochi    Skiing  Snowboard          JONES, Jenny     GBR
# 5766  2014     Sochi    Skiing  Snowboard       ANDERSON, Jamie     USA
# 5767  2014     Sochi    Skiing  Snowboard    MALTAIS, Dominique     CAN
# 5768  2014     Sochi    Skiing  Snowboard          SAMKOVA, Eva     CZE
# 5769  2014     Sochi    Skiing  Snowboard      TRESPEUCH, Chloe     FRA
#
#      Gender            Event   Medal
# 0       Men  Military Patrol  Bronze
# ...

# %% [markdown]
# 3) Display just the first 5 rows of the data

# %%
df.head()
# Out:
#    Year      City     Sport Discipline               Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon           BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon        MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon   MANDRILLON, Maurice     FRA    Men
# 3  1924  Chamonix  Biathlon   Biathlon       VANDELLE, André     FRA    Men
# 4  1924  Chamonix  Biathlon   Biathlon  AUFDENBLATTEN, Adolf     SUI    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze
# 3  Military Patrol  Bronze
# 4  Military Patrol    Gold

# %% [markdown]
# 4) Display just the last 5 rows of the data.

# %%
df.tail()
# Out:
#       Year   City   Sport Discipline             Athlete Country Gender  \
# 5765  2014  Sochi  Skiing  Snowboard        JONES, Jenny     GBR  Women
# 5766  2014  Sochi  Skiing  Snowboard     ANDERSON, Jamie     USA  Women
# 5767  2014  Sochi  Skiing  Snowboard  MALTAIS, Dominique     CAN  Women
# 5768  2014  Sochi  Skiing  Snowboard        SAMKOVA, Eva     CZE  Women
# 5769  2014  Sochi  Skiing  Snowboard    TRESPEUCH, Chloe     FRA  Women
#
#                 Event   Medal
# 5765       Slopestyle  Bronze
# 5766       Slopestyle    Gold
# 5767  Snowboard Cross  Silver
# 5768  Snowboard Cross    Gold
# 5769  Snowboard Cross  Bronze

# %% [markdown]
# 5) Display just the first 3 rows of the data.

# %%
df.head(3)
# Out:
#    Year      City     Sport Discipline              Athlete Country Gender  \
# 0  1924  Chamonix  Biathlon   Biathlon          BERTHET, G.     FRA    Men
# 1  1924  Chamonix  Biathlon   Biathlon       MANDRILLON, C.     FRA    Men
# 2  1924  Chamonix  Biathlon   Biathlon  MANDRILLON, Maurice     FRA    Men
#
#              Event   Medal
# 0  Military Patrol  Bronze
# 1  Military Patrol  Bronze
# 2  Military Patrol  Bronze

# %% [markdown]
# 6) Use the columns attribute of the DataFrame to give a list of the column names.

# %%
df.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# 7) Display the number of rows and columns in the DataFrame.

# %%
df.shape
# Out:
# (5770, 9)

# %% [markdown]
# 8) Select just the Athlete column.

# %%
df['Athlete']
# Out:
# 0                BERTHET, G.
# 1             MANDRILLON, C.
# 2        MANDRILLON, Maurice
# 3            VANDELLE, André
# 4       AUFDENBLATTEN, Adolf
#                 ...
# 5765            JONES, Jenny
# 5766         ANDERSON, Jamie
# 5767      MALTAIS, Dominique
# 5768            SAMKOVA, Eva
# 5769        TRESPEUCH, Chloe
# Name: Athlete, Length: 5770, dtype: object

# %% [markdown]
# 9) Select the columns Sport and Discipline so that they display side-by-side

# %%
df[['Sport', 'Discipline']]
# Out:
#          Sport Discipline
# 0     Biathlon   Biathlon
# 1     Biathlon   Biathlon
# 2     Biathlon   Biathlon
# 3     Biathlon   Biathlon
# 4     Biathlon   Biathlon
# ...        ...        ...
# 5765    Skiing  Snowboard
# 5766    Skiing  Snowboard
# 5767    Skiing  Snowboard
# 5768    Skiing  Snowboard
# 5769    Skiing  Snowboard
#
# [5770 rows x 2 columns]

# %% [markdown]
# 10) What are the data types of all the columns in the DataFrame?

# %%
df.dtypes
# Out:
# Year           int64
# City          object
# Sport         object
# Discipline    object
# Athlete       object
# Country       object
# Gender        object
# Event         object
# Medal         object
# dtype: object

# %% [markdown]
# 11) a) Display just the unique values in the Medal columns

# %%
df['Medal'].unique()
# Out:
# array(['Bronze', 'Gold', 'Silver'], dtype=object)

# %% [markdown]
# 11) b) Use the .shape attribute to count the number of unique values held in the Medal column

# %%
df['Medal'].unique().shape
# Out:
# (3,)

# %% [markdown]
# 12) How many unique disciplines are there in the Discipline column?

# %%
df['Discipline'].unique().shape
# Out:
# (15,)

# %% [markdown]
# 13) Calculate how many years there were between the first Winter Olympics in the data and the most recent Winter Olmpics in the data.

# %%
df['Year'].max() - df['Year'].min()
# Out:
# 90

# %% [markdown]
# 14) a) Select just the data where the discipline is snowboarding (Snowboard).

# %%
df[df['Discipline'] == 'Snowboard']
# Out:
#       Year    City   Sport Discipline             Athlete Country Gender  \
# 3605  1998  Nagano  Skiing  Snowboard    KESTENHOLZ, Ueli     SUI    Men
# 3606  1998  Nagano  Skiing  Snowboard    REBAGLIATI, Ross     CAN    Men
# 3607  1998  Nagano  Skiing  Snowboard     PRUGGER, Thomas     ITA    Men
# 3608  1998  Nagano  Skiing  Snowboard     KOECK, Brigitte     AUT  Women
# 3609  1998  Nagano  Skiing  Snowboard        RUBY, Karine     FRA  Women
# ...    ...     ...     ...        ...                 ...     ...    ...
# 5765  2014   Sochi  Skiing  Snowboard        JONES, Jenny     GBR  Women
# 5766  2014   Sochi  Skiing  Snowboard     ANDERSON, Jamie     USA  Women
# 5767  2014   Sochi  Skiing  Snowboard  MALTAIS, Dominique     CAN  Women
# 5768  2014   Sochi  Skiing  Snowboard        SAMKOVA, Eva     CZE  Women
# 5769  2014   Sochi  Skiing  Snowboard    TRESPEUCH, Chloe     FRA  Women
#
#                 Event   Medal
# 3605     Giant-Slalom  Bronze
# ...

# %% [markdown]
# 14) b) Select again the data where the discipline is snowboarding. This time, save the resulting DataFrame to a new variable called snowboard_df.

# %%
snowboard_df = df[df['Discipline'] == 'Snowboard']

# %% [markdown]
# 14) c) Using your snowboard_df DataFrame, select the data where 'Medal' is equal to 'Gold'

# %%
snowboard_df[snowboard_df['Medal'] == 'Gold']
# Out:
#       Year            City   Sport Discipline               Athlete Country  \
# 3606  1998          Nagano  Skiing  Snowboard      REBAGLIATI, Ross     CAN
# 3609  1998          Nagano  Skiing  Snowboard          RUBY, Karine     FRA
# 3612  1998          Nagano  Skiing  Snowboard          SIMMEN, Gian     SUI
# 3615  1998          Nagano  Skiing  Snowboard         THOST, Nicola     GER
# 4087  2002  Salt Lake City  Skiing  Snowboard       SCHOCH, Philipp     SUI
# 4090  2002  Salt Lake City  Skiing  Snowboard       BLANC, Isabelle     FRA
# 4093  2002  Salt Lake City  Skiing  Snowboard          POWERS, Ross     USA
# 4096  2002  Salt Lake City  Skiing  Snowboard          CLARK, Kelly     USA
# 4612  2006           Turin  Skiing  Snowboard       SCHOCH, Philipp     SUI
# 4615  2006           Turin  Skiing  Snowboard        MEULI, Daniela     SUI
# 4618  2006           Turin  Skiing  Snowboard          WHITE, Shaun     USA
# ...

# %% [markdown]
# 14) d) Select just the names of the athletes who won gold in the snowboarding.

# %%
snowboard_df[snowboard_df['Medal'] == 'Gold']['Athlete']
# Out:
# 3606        REBAGLIATI, Ross
# 3609            RUBY, Karine
# 3612            SIMMEN, Gian
# 3615           THOST, Nicola
# 4087         SCHOCH, Philipp
# 4090         BLANC, Isabelle
# 4093            POWERS, Ross
# 4096            CLARK, Kelly
# 4612         SCHOCH, Philipp
# 4615          MEULI, Daniela
# 4618            WHITE, Shaun
# 4621           TETER, Hannah
# 4624           WESCOTT, Seth
# 4627          FRIEDEN, Tanja
# 5141     ANDERSON, Jasey Jay
# 5144    SAUERBREIJ, Nicolien
# 5147            WHITE, Shaun
# 5150           BRIGHT, Torah
# 5153           WESCOTT, Seth
# 5156          RICKER, Maelle
# 5740               WILD, Vic
# 5745    PODLADTCHIKOV, Iouri
# 5747               WILD, Vic
# 5751        KOTSENBURG, Sage
# 5752        VAULTIER, Pierre
# 5757        KUMMER, Patrizia
# 5760     FARRINGTON, Kaitlyn
# 5761        DUJMOVITS, Julia
# 5766         ANDERSON, Jamie
# 5768            SAMKOVA, Eva
# Name: Athlete, dtype: object

# %% [markdown]
# 14) e) Are there any snowboarders who have won gold twice? If so, how many snowboarders have done so?

# %%
snowboard_df[snowboard_df['Medal'] == 'Gold']['Athlete'].value_counts()
# Out:
# SCHOCH, Philipp         2
# WHITE, Shaun            2
# WESCOTT, Seth           2
# WILD, Vic               2
# REBAGLIATI, Ross        1
# BRIGHT, Torah           1
# ANDERSON, Jamie         1
# DUJMOVITS, Julia        1
# FARRINGTON, Kaitlyn     1
# KUMMER, Patrizia        1
# VAULTIER, Pierre        1
# KOTSENBURG, Sage        1
# PODLADTCHIKOV, Iouri    1
# RICKER, Maelle          1
# ANDERSON, Jasey Jay     1
# SAUERBREIJ, Nicolien    1
# RUBY, Karine            1
# FRIEDEN, Tanja          1
# TETER, Hannah           1
# MEULI, Daniela          1
# CLARK, Kelly            1
# POWERS, Ross            1
# BLANC, Isabelle         1
# THOST, Nicola           1
# SIMMEN, Gian            1
# SAMKOVA, Eva            1
# Name: Athlete, dtype: int64
