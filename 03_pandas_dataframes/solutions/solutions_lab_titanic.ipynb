# %% [markdown]
# <p style="text-align: right; font-size: small;">
# Learning materials by Tamsin Huggins
# </p>

# %% [markdown]
# # Titanic Data Wrangling Solutions
#
#
# ### a) Use Pandas to load the Titanic dataset.

# %%
import pandas as pd
df = pd.read_csv('../data/titanic.csv')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           1       1  female  38.0      1      0  71.2833        C  First
# 1           1       1  female  35.0      1      0  53.1000        S  First
# 2           0       1    male  54.0      0      0  51.8625        S  First
# 3           1       3  female   4.0      1      1  16.7000        S  Third
# 4           1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 177         1       1  female  47.0      1      1  52.5542        S  First
# 178         0       1    male  33.0      0      0   5.0000        S  First
# 179         1       1  female  56.0      0      1  83.1583        C  First
# 180         1       1  female  19.0      0      0  30.0000        S  First
# 181         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 0    woman       False    C    Cherbourg   yes  False
# 1    woman       False    C  Southampton   yes  False
# 2      man        True    E  Southampton    no   True
# 3    child       False    G  Southampton   yes  False
# 4    woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 177  woman       False    D  Southampton   yes  False
# 178    man        True    B  Southampton    no   True
# 179  woman       False    C    Cherbourg   yes  False
# 180  woman       False    B  Southampton   yes   True
# 181    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %% [markdown]
# ### b) Perform data exploration on the Titanic data.
#
# Your exploration could investigate the following:
# - What do the first 5 rows of the data look like?
# - What are column names?
# - What are the datatypes of each column?
#
# Your code in the cell(s) below:

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         1       1  female  38.0      1      0  71.2833        C  First
# 1         1       1  female  35.0      1      0  53.1000        S  First
# 2         0       1    male  54.0      0      0  51.8625        S  First
# 3         1       3  female   4.0      1      1  16.7000        S  Third
# 4         1       1  female  58.0      0      0  26.5500        S  First
#
#      who  adult_male deck  embark_town alive  alone
# 0  woman       False    C    Cherbourg   yes  False
# 1  woman       False    C  Southampton   yes  False
# 2    man        True    E  Southampton    no   True
# 3  child       False    G  Southampton   yes  False
# 4  woman       False    C  Southampton   yes   True

# %%
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %% [markdown]
# ### c) Select the 'fare' column from the titanic DataFrame
#
# your code in the cell(s) below:

# %%
df['fare']
# Out:
# 0      71.2833
# 1      53.1000
# 2      51.8625
# 3      16.7000
# 4      26.5500
#         ...
# 177    52.5542
# 178     5.0000
# 179    83.1583
# 180    30.0000
# 181    30.0000
# Name: fare, Length: 182, dtype: float64

# %% [markdown]
# ### d) Investigate the fares that passengers payed to travel on the Titanic.
#
# - What is the highest fare anyone payed to ride the titanic?
# - what is the average fare payed by titanic passengers?
# - How many passengers boarded the titanic for free?
#
# Your code in the cell(s) below:

# %%
df['fare'].max()
# Out:
# 512.3292

# %%
df['fare'].mean()
# Out:
# 78.91973516483515

# %%
df[df['fare'] == 0].shape[0]
# Out:
# 2

# %% [markdown]
# ### e) What are the distinct values held in the 'class' column?
#
# In other words, what are the cateogory names held in this column?
#
# Your code in the cell(s) below:

# %%
df['class'].unique()
# Out:
# array(['First', 'Third', 'Second'], dtype=object)

# %% [markdown]
# ### f) Create a new column which holds the date of birth of each passenger. Call this new column 'D.O.B'
#
#  - Assume that the 'age' column in the data represents passengers' ages when the titanic set sail, in **1912**.
#
#  Your code in the cell(s) below:

# %%
df['D.O.B'] = 1912 - df['age']
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           1       1  female  38.0      1      0  71.2833        C  First
# 1           1       1  female  35.0      1      0  53.1000        S  First
# 2           0       1    male  54.0      0      0  51.8625        S  First
# 3           1       3  female   4.0      1      1  16.7000        S  Third
# 4           1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 177         1       1  female  47.0      1      1  52.5542        S  First
# 178         0       1    male  33.0      0      0   5.0000        S  First
# 179         1       1  female  56.0      0      1  83.1583        C  First
# 180         1       1  female  19.0      0      0  30.0000        S  First
# 181         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone   D.O.B
# 0    woman       False    C    Cherbourg   yes  False  1874.0
# 1    woman       False    C  Southampton   yes  False  1877.0
# 2      man        True    E  Southampton    no   True  1858.0
# 3    child       False    G  Southampton   yes  False  1908.0
# 4    woman       False    C  Southampton   yes   True  1854.0
# ..     ...         ...  ...          ...   ...    ...     ...
# 177  woman       False    D  Southampton   yes  False  1865.0
# 178    man        True    B  Southampton    no   True  1879.0
# 179  woman       False    C    Cherbourg   yes  False  1856.0
# 180  woman       False    B  Southampton   yes   True  1893.0
# 181    man        True    C    Cherbourg   yes   True  1886.0
#
# [182 rows x 16 columns]

# %%
df['D.O.B'] = df['D.O.B'].astype(int)  # convert from float to int

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0           1       1  female  38.0      1      0  71.2833        C  First
# 1           1       1  female  35.0      1      0  53.1000        S  First
# 2           0       1    male  54.0      0      0  51.8625        S  First
# 3           1       3  female   4.0      1      1  16.7000        S  Third
# 4           1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 177         1       1  female  47.0      1      1  52.5542        S  First
# 178         0       1    male  33.0      0      0   5.0000        S  First
# 179         1       1  female  56.0      0      1  83.1583        C  First
# 180         1       1  female  19.0      0      0  30.0000        S  First
# 181         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone  D.O.B
# 0    woman       False    C    Cherbourg   yes  False   1874
# 1    woman       False    C  Southampton   yes  False   1877
# 2      man        True    E  Southampton    no   True   1858
# 3    child       False    G  Southampton   yes  False   1908
# 4    woman       False    C  Southampton   yes   True   1854
# ..     ...         ...  ...          ...   ...    ...    ...
# 177  woman       False    D  Southampton   yes  False   1865
# 178    man        True    B  Southampton    no   True   1879
# 179  woman       False    C    Cherbourg   yes  False   1856
# 180  woman       False    B  Southampton   yes   True   1893
# 181    man        True    C    Cherbourg   yes   True   1886
#
# [182 rows x 16 columns]
