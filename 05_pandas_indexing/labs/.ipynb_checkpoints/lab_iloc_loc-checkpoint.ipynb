# %% [markdown]
# # Lab: Using `iloc` and `loc`
#
# ---

# %% [markdown]
# ### 0. Import pandas and load in the data.
# Load in colors.csv from the data folder. Save it as as a variable called colors_df.

# %% [markdown]
# ---
# ## `iloc` Challenges
#
# ---

# %% [markdown]
# ### 1. Select the row representing different shades of green using `iloc`

# %% [markdown]
# ### 2. Select the row representing different shades of orange using `iloc`

# %% [markdown]
# ### 3. Using `iloc` with slicing, select from the row representing orange to the row representing green.

# %% [markdown]
# ### 4. Using `iloc`, retrieve the values Mustard, Canary, Mint and Lime
#
# Section of data shown in the image below
#
# ![image.png](attachment:8ff4be9a-8cf5-4c90-9271-3f824f856298.png)

# %% [markdown]
# ### 5. Using `iloc`, select the section of data holding the values Gold, Lemon, Mustard, Canary, Emerald, Olive, Mint and Lime.

# %% [markdown]
# ### 6. Using `iloc`, select the section of data holding the values Lime, Forest, Cobalt, Cerulean, Lilac and Amethyst

# %% [markdown]
# ----
#
# ## `loc` challenges
#
# ---
#
# ### 7. Set the index of the colors_df DataFrame to be the Colors column.
#
# Hint: make sure the change is saved to the DataFrame.

# %% [markdown]
# ### 8. Select the row representing different shades of yellow using `loc`

# %% [markdown]
# ### 9. Select the row representing different shades of Purple using `loc`

# %% [markdown]
# ### 10. Using `loc` with slicing, select from the row representing orange to the row representing green.

# %% [markdown]
# ### 11. Using `loc` with slicing, select Shade 4 and Shade 5 of Blue
