# %% [markdown]
# <p style="text-align: right; font-size: small;">
# Learning materials by Tamsin Huggins
# </p>

# %% [markdown]
# # Logic Flow Control Challenge:  Mission Orion Game
#
# To build this successfully you will use:
# - Comparison operators( greater than, less than, equals )
# - Nested if/elif/else statements
# - Type conversion (string to int)
#
# The task
# - Build an interactive game that takes the user through a series of decisions to decide the fate of Mission Orion.
# - The user will steer the game narrative by typing their choice into an input box at each decision point.
#
# The game diagram
# - You will see a flow chart with a series of decisions for the user to make.
# - Optionally, you can change the theme of the game and design your own narrative.
#
# The code cell below will get you started.
# - Run the cell
# - You will see an input box appear
# - Play the game by typing into the input box. Explore how it behaves.
#
# ### Game Diagram
#
# ![c2-game-diagram conv 1.png](attachment:63a2f3c0-e181-43b6-a63c-ab122c99d570.png)

# %% [markdown]
# ## Starter Code, Uneditable
#
# Run this cell and play the game to get started.
#
# Once you're ready to add your own code, you should paste this starter code into a new cell and work from there

# %%
print("Welcome to Mission Orion. Your mission is to retrieve a space probe lost in the asteroid belt.")

choice1 = input('Will you direct the mission towards "Asteroid-Belt", "Ceres", or "Phobos"? Type your destination \n').lower()
if choice1 in ("asteroid-belt", "ceres"):
    choice2 = input("An asteroid is on a collision course with your spacecraft. How many of the ship's 10 thrusters do you engage? Enter a number between 0 and 10\n")
    
    # continue the game using choice2
    
elif choice1 =="phobos":
    print("You get caught in Phobos's gravitational pull and crash. Game Over.")
else:
    print(f"{choice1.capitalize()} isn't a valid destination. Game Over.")
