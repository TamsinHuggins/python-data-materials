# %% [markdown]
# # Data Cleaning Challenge Solutions
#
# This challenge involves exploration and cleaning of data, which contains some unwanted columns and some missing values.
#
# #### The dataset:
#
# The data for this challenge describes the useage and prices of oil accross different countries.
#
# You will see a file called petrol_data.csv inside the Data folder.
#
# ### a) Load in the oil data. Save it as a DataFrame under the name petrol_df.
#
# - first, import the pandas library using:
#
# import pandas as pd
#
# - Then, the dataset can be accessed using file path 'Data/petrol_data.csv'
#
# Your code in the cell(s) below:

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/petrol_data.csv')
df
# Out:
#      Unnamed: 0        Country  Daily Oil Consumption (Barrels) World Share  \
# 0             0  United States                       19687287.0      20.30%
# 1             1          China                       12791553.0      13.20%
# 2             2          India                        4443000.0       4.60%
# 3             3          Japan                        4012877.0       4.10%
# 4             4         Russia                        3631287.0       3.70%
# ..          ...            ...                              ...         ...
# 182         182          Malta                          47000.0       0.05%
# 183         183           Fiji                          16000.0       0.02%
# 184         184         Tuvalu                              NaN         NaN
# 185         185           Laos                          18000.0       0.02%
# 186         186         France                        1705568.0       1.80%
#
# ...

# %% [markdown]
# ### b) Perform some data exploration on petrol_df.
#
# Your exploration could answer the following questions:
# - What do the first 5 rows of the petrol_df DataFrame look like?
# - What are column names in petrol_df?
# - What datatypes of each column in petrol_df?
# - How many rows and columns does petrol_df have?
#
# Your code in the cell(s) below:

# %%
df.head(5)
# Out:
#    Unnamed: 0        Country  Daily Oil Consumption (Barrels) World Share  \
# 0           0  United States                       19687287.0      20.30%
# 1           1          China                       12791553.0      13.20%
# 2           2          India                        4443000.0       4.60%
# 3           3          Japan                        4012877.0       4.10%
# 4           4         Russia                        3631287.0       3.70%
#
#    Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                      934.3                    5.19                   1.37
# 1                      138.7                    5.42                   1.43
# 2                       51.4                    5.05                   1.33
# 3                      481.5                    4.69                   1.24
# 4                      383.2                    3.41                   0.90
#
#    Price Per Liter (PKR)
# 0                 289.97
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Daily Oil Consumption (Barrels)',
#        'World Share', 'Yearly Gallons Per Capita', 'Price Per Gallon (USD)',
#        'Price Per Liter (USD)', 'Price Per Liter (PKR)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0                           int64
# Country                             object
# Daily Oil Consumption (Barrels)    float64
# World Share                         object
# Yearly Gallons Per Capita          float64
# Price Per Gallon (USD)             float64
# Price Per Liter (USD)              float64
# Price Per Liter (PKR)              float64
# dtype: object

# %%
df.shape #there are 8 columns and 187 rows
# Out:
# (187, 8)

# %% [markdown]
# ### c) There is a column, 'Unnamed: 0', which is is a useless duplicate of the index column. Remove this column using the pandas .drop() method.
#
# tip1: try running a cell with the following code:
#
# petrol_df.drop?
#
# This will bring up information about the parameters (settings) that go inside the round brackets, so that you can customise the drop() function.
#
# tip2: .drop() can be used to remove rows OR columns, so you will need to specify whether to operate on rows or columns using one of the function parameters.
#
# tip3: you will need to do something to ensure that the changes are saved to the DataFrame, not just viewed.
#
# Your code in the cell(s) below:

# %%
df.drop?
# Out:
# Signature:
# df.drop(
#     labels=None,
#     axis: 'Axis' = 0,
#     index=None,
#     columns=None,
#     level: 'Level | None' = None,
#     inplace: 'bool' = False,
#     errors: 'str' = 'raise',
# )
# Docstring:
# Drop specified labels from rows or columns.
#
# Remove rows or columns by specifying label names and corresponding
# axis, or by specifying directly index or column names. When using a
# multi-index, labels on different levels can be removed by specifying
# the level. See the `user guide <advanced.shown_levels>`
# for more information about the now unused levels.
#
# Parameters
# ----------
# labels : single label or list-like
#     Index or column labels to drop. A tuple will be used as a single
#     label and not treated as a list-like.
# axis : {0 or 'index', 1 or 'columns'}, default 0
#     Whether to drop labels from the index (0 or 'index') or
#     columns (1 or 'columns').
# index : single label or list-like
# ...

# %%
df.drop(columns='Unnamed: 0', inplace=True)

# %%
df
# Out:
#            Country  Daily Oil Consumption (Barrels) World Share  \
# 0    United States                       19687287.0      20.30%
# 1            China                       12791553.0      13.20%
# 2            India                        4443000.0       4.60%
# 3            Japan                        4012877.0       4.10%
# 4           Russia                        3631287.0       3.70%
# ..             ...                              ...         ...
# 182          Malta                          47000.0       0.05%
# 183           Fiji                          16000.0       0.02%
# 184         Tuvalu                              NaN         NaN
# 185           Laos                          18000.0       0.02%
# 186         France                        1705568.0       1.80%
#
#      Yearly Gallons Per Capita  Price Per Gallon (USD)  Price Per Liter (USD)  \
# 0                        934.3                    5.19                   1.37
# ...

# %% [markdown]
# ### d)  Deal with the NaN values in the data by removing rows that contain any NaN values. Save the result to a DataFrame called petrol_clean.
#
# How many rows were removed?
#
# Tip: there is a Pandas method which allows you to drop rows containing NaN values from the DataFrame.
#
# Your code in the cell(s) below:

# %%
df.dropna(inplace=True)

# %%
df.shape #dropped two rows
# Out:
# (185, 7)

# %% [markdown]
# ### e) Save your cleaned data to a new .csv file. Call it petrol_cleaned.csv.
#
# Your code in the cell(s) below:

# %%
df.to_csv('../data/petrol_cleaned.csv') # this would put the file next to the original source file within the Data folder

# %% [markdown]
# ### f) Other than dropping rows, how else can missing data be dealt with?
#
# In no more than 100 words, offer thoughts about the following:
# - Other Pandas methods that deal with NaN values.
# - Cases where one method of dealing with NaNs may be more suitable than another method.
#
# Your written text in the cell(s) below.

# %% [markdown]
# You could use
# - fillna using bfill, ffill (can be used on categorical or numeric data)
# - fillna with the mean or median value (can only be used on numeric data)
# - fillna with a hard-coded value such as 0 (can be used on categorical or numeric data)
# - interpolate (can only be used on numeric data)
#
# dropna is a suitable method if we can accept the associated data loss. Methods for predicting and filling NaN values must be used with an awareness of how the filled data could impact the results of data analysis.
